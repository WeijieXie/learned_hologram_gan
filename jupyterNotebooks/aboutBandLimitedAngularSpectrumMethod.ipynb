# %% [markdown]
# # Band-Limited Angular Spectrum Method for Numerical Simulation of Free-Space Propagation in Far and Near Fields

# %%
import numpy as np
import math
import cmath
import matplotlib.pyplot as plt

# %% [markdown]
# ## the implementation of angular spectrum method

# %%
def AS(wave_length=1, n_S=50, band_limit=-1):
    wave_length = wave_length  # the length of the wave
    dx = 2 * wave_length  # the sampling interval
    N = 2048  #  the number of samplings
    S = 2048 * wave_length  # the size of the sampling window
    z = n_S * S  # the propagation distance

    freq = np.fft.fftfreq(N, dx)
    freq_square = freq**2
    freq_squre_max = np.full(N, 1 / wave_length) ** 2
    w_square_0 = freq_squre_max - freq_square
    mask = w_square_0 > 0
    w_square = np.where(mask, w_square_0, 0)

    # the transfer function
    H_FR = np.empty(N, dtype=complex)
    H_FR = np.exp(2j * math.pi * z * np.sqrt(w_square))
    # H_FR = np.exp(1j * math.pi * z * (2 / wave_length - wave_length * (freq_square)))

    # generate the source plain spectrum
    g_0 = np.zeros(N)
    g_0[int(N / 2) - 256 : int(N / 2) + 256] = np.ones(int(512))

    G_0 = np.fft.fft(g_0)

    # the dest plain spectrum
    G_z = G_0 * H_FR

    if band_limit == -1:
        pass
    else:
        # limit the bandwidth
        G_z = np.fft.fftshift(G_z)
        f = band_limit
        G_z[0 : N // 2 + 1 - f] = np.zeros(N // 2 + 1 - f)
        G_z[N // 2 + f : N] = np.zeros(N // 2 - f)
        G_z = np.fft.ifftshift(G_z)

    # the dest plain
    g_z = abs(np.fft.ifft(G_z))

    return H_FR.real, g_z[int(N / 2) - 512 : int(N / 2) + 512]

# %%
H_FR, g_z_AS = AS(1,50,-1)
plt.plot(g_z_AS, label="AS_result")

plt.legend()
plt.show()

# %% [markdown]
# ## the implementation of numerical integration

# %%
from numba import njit


@njit(parallel=True)
def numerical_integration(wave_length=1, n_S=50):
    wave_length = wave_length  # the length of the wave
    dx = 2 * wave_length  # the sampling interval
    N = 1024  #  the number of samplings
    S = 2048 * wave_length  # the size of the sampling window
    z = n_S * S  # the propagation distance

    # real = np.zeros(1024)
    # imag = np.zeros(1024)
    inte_result = np.zeros(1024)

    N = 4000

    g_src = np.zeros(N)
    g_src[int(N / 4) : int(N / 4 * 3)] = np.ones(int(N / 2))

    y_real = np.zeros(N)
    y_imag = np.zeros(N)
    x = np.zeros(N)

    d_x = S / N
    for k in range(0, N):
        x[k] = d_x * k

    d_x_dest = 2 * wave_length

    for x_dest_n in range(0, 1024):
        for k in range(0, N):
            r = math.sqrt(z**2 + (x_dest_n * d_x_dest - x[k]) ** 2)
            exp = cmath.exp(2j * math.pi * r / wave_length)
            # print(x_dest_n * d_x_dest - x[k])
            # print(r)
            # print(exp)
            fx = (
                g_src[k]
                * (exp / r)
                * (z / r)
                * (1 / (2 * math.pi * r) + 1 / (1j * wave_length))
            )
            y_real[k] = fx.real
            y_imag[k] = fx.imag
        inte_result[x_dest_n] = abs(np.sum(y_real * d_x) + np.sum(1j * y_imag * d_x))
        # inte_result[x_dest_n] = abs(
        #     np.sum(np.multiply(fx, dx))
        # )
        # real[x_dest_n]=0.5*d_x*(2*np.sum(y_real)-y_real[0]-y_real[-1])
        # imag[x_dest_n]=0.5*d_x*(2*np.sum(y_imag)-y_imag[0]-y_imag[-1])

        inte_result_g = inte_result

    return inte_result_g

# %%
g_z = numerical_integration(1,50)
plt.plot(g_z, label="numerical_integration")

plt.legend()
plt.show()

# %% [markdown]
# ## the AS evaluator

# %%
def AS_evaluator(wave_length=1, n_S=50):
    wave_length = wave_length  # the length Fof the wave
    dx = 2 * wave_length  # the sampling interval
    N = 1024 * 1024   #  the number of samplings
    S = 2048 * wave_length  # the size of the sampling window
    z = n_S * S  # the propagation distance

    freq = np.fft.fftfreq(N, dx)
    freq_square = freq**2
    freq_squre_max = np.full(N, 1 / wave_length) ** 2
    w_square_0 = freq_squre_max - freq_square
    mask = w_square_0 > 0
    w_square = np.where(mask, w_square_0, 0)

    # the transfer function
    H_FR = np.empty(N, dtype=complex)
    H_FR = np.exp(2j * math.pi * z * np.sqrt(w_square))
    # H_FR = np.exp(1j * math.pi * z * (2 / wave_length - wave_length * (freq_square)))

    # generate the source plain spectrum
    g_0 = np.zeros(N)
    g_0[int(N / 2) - 256 : int(N / 2) + 256] = np.ones(int(512))

    G_0 = np.fft.fft(g_0)

    # the dest plain spectrum
    G_z = G_0 * H_FR

    # the dest plain
    g_z = abs(np.fft.ifft(G_z))

    return g_z[int(N / 2) - 512 : int(N / 2) + 512]

# %%
g_z_AS_evaluator = AS_evaluator(1,50)
plt.plot(g_z_AS_evaluator, label="AS_result")

plt.legend()
plt.show()

# %% [markdown]
# ## the SNR of angular spectrum method with different propagation distances

# %%
def SNR_cal(signal, noisy_signal):
    # signal_power = np.mean(np.square(signal))
    # noise_power = np.mean(np.square(noisy_signal - signal))
    signal_power = np.mean(np.square(signal))
    noise_power = abs(np.mean(np.square(noisy_signal)) - np.mean(np.square(signal)))
    snr_db = 10 * np.log10(signal_power / noise_power)
    return snr_db

# %%
SNR = []

n_S_list = list(np.linspace(-1, 2, 100))

for n_S in n_S_list:
    n_S = 10**n_S
    AS_spectrum, AS_result = AS(1, n_S, -1)
    SNR.append(SNR_cal(AS_evaluator(1, n_S), AS_result))

# %%
x = 10 ** np.array(n_S_list)
plt.plot(x, SNR)

plt.title("the SNR of band-limited AS")
plt.xlabel("the propagation distance z [Sx]")
plt.ylabel("SNR [dB]")

plt.xscale("log")
plt.show()

# %% [markdown]
# ## improve the SNR by limiting the bandwidth

# %% [markdown]
# ### implement of band-limited angular spectrum method

# %%
def band_limited_AS(wave_length, n_S):
    wave_length = wave_length  # the length Fof the wave
    dx = 2 * wave_length  # the sampling interval
    N = 2048  #  the number of samplings
    S = 2048 * wave_length  # the size of the sampling window
    z = n_S * S  # the propagation distance

    freq = np.fft.fftfreq(N, dx)
    freq = np.fft.fftshift(freq)

    d_u = 1 / (2 * S)
    u_limit = 1 / (np.sqrt((2 * d_u * z) ** 2 + 1) * wave_length)

    mask = abs(freq) <= (u_limit)
    if np.all(mask):
        clipper_n = -1
        max_frequency_retained = abs(freq[0])
    else:
        first_true_index = np.argmax(mask)
        clipper_n = N // 2 + 1 - first_true_index
        max_frequency_retained = abs(freq[first_true_index])

    H_FR_real, g_z = AS(1, n_S, clipper_n)

    print(
        f"under cut-off frequency {(u_limit)} : set clipper_n to be {clipper_n} (the max frequency retained : {max_frequency_retained})"
    )

    return max_frequency_retained, g_z

# %%
band_limited_AS_spectrum, band_limited_AS_result = band_limited_AS(1, 50)
AS_spectrum, AS_result = AS(1, 50, -1)

SNR_band_limited_AS_spectrum = SNR_cal(AS_evaluator(1, 50), band_limited_AS_result)
print(SNR_band_limited_AS_spectrum)

plt.plot(AS_result, label="AS_result",color='yellow')
plt.plot(band_limited_AS_result, label="band_limited_AS_result",color='blue')
plt.plot(AS_evaluator(1,50), label="AS_evaluator",color='green')

plt.legend()
plt.show()
# Out:
# under cut-off frequency 0.01999600119960014 : set clipper_n to be 82 (the max frequency retained : 0.019775390625)
# 46.43677700406104

# %% [markdown]
# ### SNR of band-limited angular spectrum with different propagation distance

# %%
SNR_band_limited = []

n_S_list = list(np.linspace(-1, 2, 100))

for n_S in n_S_list:
    n_S = 10**n_S
    band_limited_AS_spectrum, band_limited_AS_result = band_limited_AS(1, n_S)
    AS_spectrum, AS_result = AS(1, n_S, -1)

    numerical_result = numerical_integration(1, n_S)
    SNR_band_limited.append(SNR_cal(AS_evaluator(1, n_S), band_limited_AS_result))
# Out:
# under cut-off frequency 0.9950371902099893 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9943003175733328 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.993455112909366 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9924859915972368 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9913752349691566 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9901027321227495 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9886457013651091 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9869783934070472 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9850717800622875 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9828932343539792 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9804062106841427 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9775699371685375 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9743391364464262 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9706637962636857 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.966489016843556 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9617549683266952 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9563969980326608 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9503459333872334 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9435286312026566 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9358688263891017 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9272883315844841 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.9177086318304253 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.907052903438699 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8952484619848375 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8822296100682426 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8679408115580389 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8523400679174646 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8354023186898921 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.8171226396216269 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.7975189773435907 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.7766341486684476 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.754536853388063 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.7313215059301937 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.7071067811865475 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.6820328840781752 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.6562576756726285 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.6299519022290794 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.6032938593892971 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.5764638686143171 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.5496389414220499 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.5229879622156248 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.49666764302899047 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.47081940817986334 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.44556726912306166 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.42101666280971145 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.3972541592783252 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.37434789983017663 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.35234860549331726 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.33129099308740845 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.3111954480617418 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.2920698241073782 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.27391126464407667 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.25670796699903237 : set clipper_n to be -1 (the max frequency retained : 0.25)
# under cut-off frequency 0.24044083393419297 : set clipper_n to be 985 (the max frequency retained : 0.240234375)
# under cut-off frequency 0.2250849777058267 : set clipper_n to be 922 (the max frequency retained : 0.224853515625)
# under cut-off frequency 0.2106110584568186 : set clipper_n to be 863 (the max frequency retained : 0.21044921875)
# under cut-off frequency 0.19698645144263197 : set clipper_n to be 807 (the max frequency retained : 0.19677734375)
# under cut-off frequency 0.18417624673440808 : set clipper_n to be 755 (the max frequency retained : 0.18408203125)
# under cut-off frequency 0.17214409117049703 : set clipper_n to be 706 (the max frequency retained : 0.172119140625)
# under cut-off frequency 0.16085288604076775 : set clipper_n to be 659 (the max frequency retained : 0.16064453125)
# under cut-off frequency 0.15026535586186052 : set clipper_n to be 616 (the max frequency retained : 0.150146484375)
# under cut-off frequency 0.14034450414272368 : set clipper_n to be 575 (the max frequency retained : 0.14013671875)
# under cut-off frequency 0.13105397166759059 : set clipper_n to be 537 (the max frequency retained : 0.130859375)
# under cut-off frequency 0.1223583118682579 : set clipper_n to be 502 (the max frequency retained : 0.122314453125)
# under cut-off frequency 0.11422319656811905 : set clipper_n to be 468 (the max frequency retained : 0.114013671875)
# under cut-off frequency 0.106615563936834 : set clipper_n to be 437 (the max frequency retained : 0.1064453125)
# under cut-off frequency 0.09950371902099892 : set clipper_n to be 408 (the max frequency retained : 0.099365234375)
# under cut-off frequency 0.09285739579387559 : set clipper_n to be 381 (the max frequency retained : 0.0927734375)
# under cut-off frequency 0.08664778834521122 : set clipper_n to be 355 (the max frequency retained : 0.08642578125)
# under cut-off frequency 0.08084755763646888 : set clipper_n to be 332 (the max frequency retained : 0.080810546875)
# under cut-off frequency 0.0754308191875012 : set clipper_n to be 309 (the max frequency retained : 0.0751953125)
# under cut-off frequency 0.07037311613744375 : set clipper_n to be 289 (the max frequency retained : 0.0703125)
# under cut-off frequency 0.06565138132843606 : set clipper_n to be 269 (the max frequency retained : 0.0654296875)
# under cut-off frequency 0.061243891385066584 : set clipper_n to be 251 (the max frequency retained : 0.06103515625)
# under cut-off frequency 0.05713021519279031 : set clipper_n to be 235 (the max frequency retained : 0.05712890625)
# under cut-off frequency 0.05329115870215649 : set clipper_n to be 219 (the max frequency retained : 0.05322265625)
# under cut-off frequency 0.049708707590047 : set clipper_n to be 204 (the max frequency retained : 0.049560546875)
# under cut-off frequency 0.046365968982651905 : set clipper_n to be 190 (the max frequency retained : 0.046142578125)
# under cut-off frequency 0.04324711317710126 : set clipper_n to be 178 (the max frequency retained : 0.043212890625)
# under cut-off frequency 0.04033731608022099 : set clipper_n to be 166 (the max frequency retained : 0.040283203125)
# under cut-off frequency 0.03762270290567658 : set clipper_n to be 155 (the max frequency retained : 0.03759765625)
# under cut-off frequency 0.035090293527829754 : set clipper_n to be 144 (the max frequency retained : 0.034912109375)
# under cut-off frequency 0.03272794977601163 : set clipper_n to be 135 (the max frequency retained : 0.03271484375)
# under cut-off frequency 0.030524324861586613 : set clipper_n to be 126 (the max frequency retained : 0.030517578125)
# under cut-off frequency 0.02846881505792659 : set clipper_n to be 117 (the max frequency retained : 0.0283203125)
# under cut-off frequency 0.026551513696719282 : set clipper_n to be 109 (the max frequency retained : 0.0263671875)
# under cut-off frequency 0.024763167499977617 : set clipper_n to be 102 (the max frequency retained : 0.024658203125)
# under cut-off frequency 0.02309513523328725 : set clipper_n to be 95 (the max frequency retained : 0.02294921875)
# under cut-off frequency 0.021539348640241648 : set clipper_n to be 89 (the max frequency retained : 0.021484375)
# under cut-off frequency 0.020088275599039487 : set clipper_n to be 83 (the max frequency retained : 0.02001953125)
# under cut-off frequency 0.01873488542852578 : set clipper_n to be 77 (the max frequency retained : 0.0185546875)
# under cut-off frequency 0.017472616261462296 : set clipper_n to be 72 (the max frequency retained : 0.017333984375)
# under cut-off frequency 0.016295344396629354 : set clipper_n to be 67 (the max frequency retained : 0.01611328125)
# under cut-off frequency 0.01519735553777774 : set clipper_n to be 63 (the max frequency retained : 0.01513671875)
# under cut-off frequency 0.014173317825886694 : set clipper_n to be 59 (the max frequency retained : 0.01416015625)
# under cut-off frequency 0.01321825657117635 : set clipper_n to be 55 (the max frequency retained : 0.01318359375)
# under cut-off frequency 0.01232753059249705 : set clipper_n to be 51 (the max frequency retained : 0.01220703125)
# under cut-off frequency 0.011496810073773818 : set clipper_n to be 48 (the max frequency retained : 0.011474609375)
# under cut-off frequency 0.010722055849883701 : set clipper_n to be 44 (the max frequency retained : 0.010498046875)
# under cut-off frequency 0.009999500037496875 : set clipper_n to be 41 (the max frequency retained : 0.009765625)

# %% [markdown]
# the print output above shows different clipper_n regarding to different distance z

# %%
x = 10 ** np.array(n_S_list)
plt.plot(x, SNR_band_limited)

plt.title("the SNR of band-limited angular spectrum")
plt.xlabel("the propagation distance z [Sx]")
plt.ylabel("SNR [dB]")

plt.xscale("log")

plt.show()

# %% [markdown]
# ### the improvement in SNR

# %%
x = 10 ** np.array(n_S_list)
plt.plot(x, np.array(SNR_band_limited) - np.array(SNR))

plt.title("the SNR of band-limited AS minus original AS")
plt.xlabel("the propagation distance z [Sx]")
plt.ylabel("SNR [dB]")

plt.xscale("log")

plt.show()

# %% [markdown]
# ### the clipper's effect on SNR

# %%
SNR_clipper = []

n_Sx = 50

n_clipper_list = list(np.linspace(1, 400, 400))
numerical_result = numerical_integration(1, n_Sx)
AS_spectrum, AS_result = AS(1, n_Sx, -1)
evaluator = AS_evaluator(1, n_Sx)

for n_clipper in n_clipper_list:
    band_limited_AS_spectrum, band_limited_AS_result = AS(1, n_Sx, int(n_clipper))
    SNR_clipper.append(SNR_cal(evaluator, band_limited_AS_result))

# %%
wave_length = 1  # the length of the wave
dx = 2 * wave_length  # the sampling interval
N = 2048  #  the number of samplings
S = 2048 * wave_length  # the size of the sampling window
z = n_Sx * S  # the propagation distance

freq = np.fft.fftfreq(N, dx)

max_frequency_retained, g_z = band_limited_AS(wave_length, n_Sx)
u_freq = 1 / math.sqrt((2 * z / (1.5 * S)) ** 2 + 1) / wave_length
u_bandwidth = 2*u_freq
aliasing_bandwidth = 2 * max_frequency_retained

print(f"bandwidth needed: {u_bandwidth}")
print(f"bandwidth of band-limited AS: {aliasing_bandwidth}")


plt.plot(2 * freq[0:400], SNR_clipper)

plt.axvline(x=u_bandwidth, color="r", linestyle="--", label="u_bandwidth")
plt.axvline(x=aliasing_bandwidth, color="g", linestyle="--", label="aliasing_bandwidth")


plt.title(f"SNR of different bandwidth when distance is {n_Sx}*Sx")

plt.xlabel("bandwidth")
plt.ylabel("SNR [dB]")

plt.legend()
plt.show()
# Out:
# under cut-off frequency 0.01999600119960014 : set clipper_n to be 82 (the max frequency retained : 0.019775390625)
# bandwidth needed: 0.029996625569424482
# bandwidth of band-limited AS: 0.03955078125

# %% [markdown]
# # 2-D comparison of AS and band-limited AS

# %%
import torch

# %%
def AS_2D(
    source_plain=-1,
    wave_length=1,
    z=100 * 2048, # the propagation distance
    sample_u=1024,  # the number of pixels in x-axis
    sample_v=1024,  # the number of pixels in y-axis
    clipper_u=-1,
    clipper_v=-1,
):
    dx = 2 * wave_length  # the sample interval

    N_u = 2 * sample_u
    N_v = 2 * sample_v

    # generate the 2-D frequency mesh
    freq_x = torch.fft.fftfreq(N_u, dx)
    freq_y = torch.fft.fftfreq(N_v, dx)

    freq_x = torch.unsqueeze(freq_x, dim=1).expand(
        -1, len(freq_y)
    )  # expand to len(y) columns
    freq_y = torch.unsqueeze(freq_y, dim=0).expand(
        len(freq_x), -1
    )  # expand to len(x) rows
    freq_square = freq_x**2 + freq_y**2

    freq_squre_max = torch.full((N_u, N_v), 1 / wave_length) ** 2
    w_square_0 = freq_squre_max - freq_square
    mask = w_square_0 > 0
    w_square = torch.where(mask, w_square_0, 0)

    # transfer function
    H_FR = torch.empty((N_u, N_v), dtype=torch.complex64)
    H_FR = torch.exp(2j * math.pi * z * torch.sqrt(w_square))

    # generate the source plain
    g_0 = torch.zeros((N_u, N_v))
    if isinstance(source_plain, torch.Tensor):
        # load the picture
        g_0[
            N_u // 2 - sample_u // 2 : N_u // 2 + sample_u // 2,
            N_v // 2 - sample_v // 2 : N_v // 2 + sample_v // 2,
        ] = source_plain
    else:
        # a simple square
        g_0[
            N_u // 2 - 256 : N_u // 2 + 256,
            N_v // 2 - 256 : N_v // 2 + 256,
        ] = torch.ones((512, 512))

    G_0 = torch.fft.fft2(g_0)

    # the spectrum in the destination plain
    G_z = G_0 * H_FR

    G_z = torch.fft.fftshift(G_z)
    # clip the frequency in x
    if clipper_u == -1:
        pass
    else:
        G_z[: N_u // 2 + 1 - clipper_u, :] = 0
        G_z[N_u // 2 + clipper_u :, :] = 0

    # clip the frequency in y
    if clipper_v == -1:
        pass
    else:
        G_z[:, : N_v // 2 + 1 - clipper_v] = 0
        G_z[:, N_v // 2 + clipper_v :] = 0

    G_z = torch.fft.ifftshift(G_z)


    # 目标平面
    g_z = torch.fft.ifft2(G_z).abs()

    return (
        H_FR.real,
        g_z[
            int(N_u / 2) - sample_u // 2 : int(N_u / 2) + sample_u // 2,
            int(N_v / 2) - sample_v // 2 : int(N_v / 2) + sample_v // 2,
        ],
    )

# %%
def band_limited_AS_2D(source_plain = -1, wave_length=1, z=100 * 2048, sample_u=1024, sample_v=1024):
    dx = 2 * wave_length  # the sampling interval
    S_x = sample_u * dx
    S_y = sample_v * dx

    N_u = 2 * sample_u
    N_v = 2 * sample_v

    freq_u = torch.fft.fftfreq(N_u, dx)
    freq_u = torch.fft.fftshift(freq_u)

    freq_v = torch.fft.fftfreq(N_v, dx)
    freq_v = torch.fft.fftshift(freq_v)

    d_u = 1 / (2 * S_x)
    d_v = 1 / (2 * S_y)
    u_limit = 1 / (math.sqrt((2 * d_u * z) ** 2 + 1) * wave_length)
    v_limit = 1 / (math.sqrt((2 * d_v * z) ** 2 + 1) * wave_length)

    mask_u = abs(freq_u) <= (u_limit)
    if torch.all(mask_u):
        clipper_u = -1
        max_frequency_retained_u = abs(freq_u[0])
    else:
        first_true_index = torch.argmax(mask_u.to(torch.int))
        clipper_u = N_u // 2 + 1 - first_true_index
        max_frequency_retained_u = abs(freq_u[first_true_index])

    mask_v = abs(freq_v) <= (v_limit)
    if torch.all(mask_v):
        clipper_v = -1
        max_frequency_retained_v = abs(freq_v[0])
    else:
        first_true_index = torch.argmax(mask_v.to(torch.int))
        clipper_v = N_v // 2 + 1 - first_true_index
        max_frequency_retained_v = abs(freq_v[first_true_index])

    H_FR_real, g_z = AS_2D(source_plain, wave_length, z, sample_u, sample_v, clipper_u, clipper_v)

    print(
        f"u: cut-off frequency {(u_limit)} : set clipper_n to be {clipper_u} (the max frequency retained : {max_frequency_retained_u})\n",
        f"v: cut-off frequency {(v_limit)} : set clipper_n to be {clipper_v} (the max frequency retained : {max_frequency_retained_v})\n",
    )

    return max_frequency_retained_u, max_frequency_retained_v, g_z

# %%
H_FR_2D, g_z_2D = AS_2D()
u, v, band_limited_g_z_2D = band_limited_AS_2D()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

im1 = axes[0].imshow(g_z_2D, cmap="gray")
fig.colorbar(im1, ax=axes[0])
axes[0].set_title("original method")

im2 = axes[1].imshow(band_limited_g_z_2D, cmap="gray")
fig.colorbar(im2, ax=axes[1])
axes[1].set_title("with band limit")

plt.tight_layout()
plt.show()
# Out:
# u: cut-off frequency 0.009999500037496875 : set clipper_n to be 41 (the max frequency retained : 0.009765625)
#  v: cut-off frequency 0.009999500037496875 : set clipper_n to be 41 (the max frequency retained : 0.009765625)
